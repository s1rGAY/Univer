# %%
import string,random
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter

# %%
def visualisation(password):
    sns.lineplot(x=Counter(password).keys(), y=Counter(password).values())

# %%
# %%time
def pass_generation(lenth):
    password = ''
    for i in range(lenth):
        password = password + random.choice(string.ascii_lowercase)
    #visualisation(password)
    return password
# Out:
# CPU times: user 4 µs, sys: 2 µs, total: 6 µs
# Wall time: 7.63 µs

# %%
def average_brute_forse_time(password):
    
    my_turbo_cpu = 4200000000*6
    
    lll = pow(26, len(password))
    
    print(lll/my_turbo_cpu)

# %%
def raspredelenie():
    password=''
    for a in range(10):
        password = password + pass_generation(32)
    visualisation(password)
raspredelenie()

# %%
average_brute_forse_time(password)
# Out:
# 1464027307.437266

# %%
def length_and_time():
    a = {1:0,2:0,3:0,4:0.2833,5:10,6:360}
    aa = {8:1,9:32,10:1162,11:41823}
    
    x = a.keys()
    y = a.values()
    fig, ax = plt.subplots()
    ax.plot(x, y)
    plt.xlabel("Length")
    plt.ylabel("Mins")
    ax.grid()
    plt.show()
    
    aa = {8:1,9:32,10:1162,11:41823}

    fig, ax = plt.subplots()
    xx, yy = aa.keys(), aa.values()
    ax.plot(xx, yy)
    plt.xlabel("Length")
    plt.ylabel("Years")
    ax.grid()
    plt.show()

# %%
length_and_time()
